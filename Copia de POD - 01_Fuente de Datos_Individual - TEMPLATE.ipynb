# %% [markdown]
# *   **Año:** [2024]
# *   **Alumno/a:** [Manuel Guerrero]
# *   **Legajo:** [46904766]

# %% [markdown]
# # Archivos de texto plano
#
# [gutenberg.org](https://www.gutenberg.org/) (llamado así por el inventor de la imprenta moderna) es el sitio web del Proyecto Gutenberg que se dedica a la distribución y creación de eBooks. En este sitio se encuentra el [Don Quijote](https://www.gutenberg.org/ebooks/14859). El Don Quijote se puede leer en diferentes formatos, ¿no? Para la tarea, se va a usar el Don Quijote de texto plano. La siguiente celda descarga el .txt y lo guarda en el sistema para luego su futura lectura:

# %%
# !wget https://www.gutenberg.org/cache/epub/2000/pg2000.txt
# Out:
# --2024-11-18 23:57:04--  https://www.gutenberg.org/cache/epub/2000/pg2000.txt
# Resolving www.gutenberg.org (www.gutenberg.org)... 152.19.134.47, 2610:28:3090:3000:0:bad:cafe:47
# Connecting to www.gutenberg.org (www.gutenberg.org)|152.19.134.47|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2225845 (2.1M) [text/plain]
# Saving to: ‘pg2000.txt’
#
# pg2000.txt          100%[===================>]   2.12M  4.90MB/s    in 0.4s
#
# 2024-11-18 23:57:05 (4.90 MB/s) - ‘pg2000.txt’ saved [2225845/2225845]

# %% [markdown]
# ## Consignas

# %% [markdown]
# ***NOTA: Para estas consignas, no se puede usar modulos externos a Python***

# %% [markdown]
# Del archivo descargado, calcular la cantidad de lineas:

# %%
#Escribir el codigo para responder la pregunta en esta celd
with open("pg2000.txt","r")as f:
  lines = f.readlines()
  print(len(lines))
# Out:
# 38055

# %% [markdown]
# Del archivo descargado, calcular la cantidad de veces que se dice:
# *   'Quijote'
# *   'mancha'
# *   'españa'
#
# Considerar que, por ejemplo, 'QuiJoTe' es lo mismo que 'quijote' (no *case sensitive*).

# %%
#Escribir el codigo para responder la pregunta en esta celda
with open("pg2000.txt","r")as file:
  txt = file.read()
normalizado = txt.lower()
stripeado = normalizado.strip()
spliteado = stripeado.split()
cquijote = 0
cmancha = 0
cespaña = 0
for word in spliteado:
  if "quijote" in word:
    cquijote += 1
  if "mancha" in word:
    cmancha += 1
  if "españa" in word:
    cespaña += 1
print(cquijote)
print(cmancha)
print(cespaña)
# Out:
# 2249
# 196
# 78

# %% [markdown]
# ¿Quien es el autor y titulo del libro? Responderlo usando las herramientas utilizadas en la celda anterior (Tip: abrir el archivo de texto y ver como son las primeras lineas).

# %%
#Escribir el codigo para responder la pregunta en esta celda
with open("pg2000.txt","r")as f:
  lines = f.readlines()
  print(lines[0])
# Out:
# ﻿The Project Gutenberg eBook of Don Quijote

# %% [markdown]
# # Archivos .csv
#
# *Robert* De Niro actuó en mas de 100 peliculas y Rotten Tomatoes es un sitio web en el que se pueden leer criticas y ratings a peliculas hechos por críticos y usuarios. La siguiente linea descarga un archivo .csv en el que tenemos peliculas de De Niro junto a su rating en Rotten Tomatoes:

# %%
# !wget https://people.sc.fsu.edu/~jburkardt/data/csv/deniro.csv
# Out:
# --2024-11-14 21:53:21--  https://people.sc.fsu.edu/~jburkardt/data/csv/deniro.csv
# Resolving people.sc.fsu.edu (people.sc.fsu.edu)... 144.174.0.22
# Connecting to people.sc.fsu.edu (people.sc.fsu.edu)|144.174.0.22|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2391 (2.3K) [text/csv]
# Saving to: ‘deniro.csv’
#
# deniro.csv          100%[===================>]   2.33K  --.-KB/s    in 0s
#
# 2024-11-14 21:53:22 (631 MB/s) - ‘deniro.csv’ saved [2391/2391]

# %% [markdown]
# ## Consignas

# %% [markdown]
# ***NOTA: Apartir de aca, se pueden usar modulos externos de Python***

# %% [markdown]
# Sabemos que el archivo tiene en su primera linea los 'headers'. ¿Cuales son? Imprimirlos.

# %%
#Escribir el codigo para responder la pregunta en esta celda
import csv
with open("deniro.csv","r")as f:
  reader = csv.reader(f)
  headers = next(reader)
  print(headers)
# Out:
# ['Year', ' "Score"', ' "Title"']

# %% [markdown]
# Convertir la información del archivo .csv a un diccionario.

# %%
#Escribir el codigo para responder la pregunta en esta celda
import csv
with open("deniro.csv","r")as file:
  lista=[]
  reader = csv.DictReader(file, quotechar = '"', delimiter=',', skipinitialspace=True)
  for row in reader:
    lista.append(row)

file.close()
for item in lista:
  item["Year"] = int(item.get("Year"))
  item["Score"] = int(item.get("Score"))
print(lista)
# Out:
# [{'Year': 1968, 'Score': 86, 'Title': 'Greetings'}, {'Year': 1970, 'Score': 17, 'Title': 'Bloody Mama'}, {'Year': 1970, 'Score': 73, 'Title': 'Hi, Mom!'}, {'Year': 1971, 'Score': 40, 'Title': 'Born to Win'}, {'Year': 1973, 'Score': 98, 'Title': 'Mean Streets'}, {'Year': 1973, 'Score': 88, 'Title': 'Bang the Drum Slowly'}, {'Year': 1974, 'Score': 97, 'Title': 'The Godfather, Part II'}, {'Year': 1976, 'Score': 41, 'Title': 'The Last Tycoon'}, {'Year': 1976, 'Score': 99, 'Title': 'Taxi Driver'}, {'Year': 1977, 'Score': 47, 'Title': '1900'}, {'Year': 1977, 'Score': 67, 'Title': 'New York, New York'}, {'Year': 1978, 'Score': 93, 'Title': 'The Deer Hunter'}, {'Year': 1980, 'Score': 97, 'Title': 'Raging Bull'}, {'Year': 1981, 'Score': 75, 'Title': 'True Confessions'}, {'Year': 1983, 'Score': 90, 'Title': 'The King of Comedy'}, {'Year': 1984, 'Score': 89, 'Title': 'Once Upon a Time in America'}, {'Year': 1984, 'Score': 60, 'Title': 'Falling in Love'}, {'Year': 1985, 'Score': 98, 'Title': 'Brazil'}, {'Year': 1986, 'Score': 65, 'Title': 'The Mission'}, {'Year': 1987, 'Score': 100, 'Title': 'Dear America: Letters Home From Vietnam'}, {'Year': 1987, 'Score': 80, 'Title': 'The Untouchables'}, {'Year': 1987, 'Score': 78, 'Title': 'Angel Heart'}, {'Year': 1988, 'Score': 96, 'Title': 'Midnight Run'}, {'Year': 1989, 'Score': 64, 'Title': 'Jacknife'}, {'Year': 1989, 'Score': 47, 'Title': "We're No Angels"}, {'Year': 1990, 'Score': 88, 'Title': 'Awakenings'}, {'Year': 1990
# %% [markdown]
# ¿Cuantas peliculas hay registradas en el archivo .csv?

# %%
#Escribir el codigo para responder la pregunta en esta celda
print(len(lista))
# Out:
# 87

# %% [markdown]
# Imprimir las peliculas mejor y peor rankeadas del archivo (imprimir sus respectivos rankings)

# %%
#Escribir el codigo para responder la pregunta en esta celda
mejorscore = lista[0].get("Score")
peorscore = lista[0].get("Score")
mejorpelicula = lista[0].get("Title")
peorpelicula = lista[0].get("Title")
for item in lista:
  if item.get("Score")> mejorscore:
    mejorscore = item.get("Score")
    mejorpelicula = item.get("Title")
  if item.get("Score")< peorscore:
    peorscore = item.get("Score")
    peorpelicula = item.get("Title")
print(f"mejor pelicula: \"{mejorpelicula}\"con el score: {mejorscore}")
print(f"peor pelicula: \"{peorpelicula}\"con el peor score: {peorscore}")
# Out:
# mejor pelicula: "Dear America: Letters Home From Vietnam"con el score: 100
# peor pelicula: "Godsend"con el peor score: 4

# %% [markdown]
# # Base de datos - Relacionales
#
# SQLite es una biblioteca de C que provee una base de datos ligera basada en disco que no requiere un proceso de servidor separado y permite acceder a la base de datos usando una variación no estándar del lenguaje de consulta SQL. Algunas aplicaciones pueden usar SQLite para almacenamiento interno. También es posible prototipar una aplicación usando SQLite y luego transferir el código a una base de datos más grande como PostgreSQL u Oracle.

# %% [markdown]
# Realizamos el `import` e indicamos el archivo en el que vamos a guardar la base de datos:

# %%
import sqlite3
conn = sqlite3.connect('db.db')

# %% [markdown]
# La siguiente linea de codigo agrega filas a la misma. Por favor, ejecutar la siguiente celda para la consigna:

# %%
# !wget https://people.sc.fsu.edu/~jburkardt/data/csv/snakes_count_10000.csv

cur = conn.cursor()
cur.execute("CREATE TABLE t (GameNumber, GameLength);")

with open('snakes_count_10000.csv','r') as csv_file:
  lines = csv_file.readlines()[1:]
  lines = [l.split(',') for l in lines]
  to_db = [(l[0].strip(), l[1].strip()) for l in lines]

cur.executemany("INSERT INTO t (GameNumber, GameLength) VALUES (?, ?);", to_db)
conn.commit()
conn.close()
# Out:
# --2024-11-14 21:53:26--  https://people.sc.fsu.edu/~jburkardt/data/csv/snakes_count_10000.csv
# Resolving people.sc.fsu.edu (people.sc.fsu.edu)... 144.174.0.22
# Connecting to people.sc.fsu.edu (people.sc.fsu.edu)|144.174.0.22|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 89011 (87K) [text/csv]
# Saving to: ‘snakes_count_10000.csv’
#
# snakes_count_10000. 100%[===================>]  86.92K  --.-KB/s    in 0.1s
#
# 2024-11-14 21:53:26 (754 KB/s) - ‘snakes_count_10000.csv’ saved [89011/89011]

# %% [markdown]
# ## Consignas

# %% [markdown]
# ¿Como luce la base de datos? Imprimirla.

# %%
#Escribir el codigo para responder la pregunta en esta celda
print(to_db)
# Out:
'14'), ('197', '11'), ('198', '43'), ('199', '48'), ('200', '19'), ('201', '40'), ('202', '197'), ('203', '33'), ('204', '41'), ('205', '28'), ('206', '25'), ('207', '17'), ('208', '62'), ('209', '17'), ('210', '71'), ('211', '30'), ('212', '41'), ('213', '17'), ('214', '51'), ('215', '9'), ('216', '33'), ('217', '47'), ('218', '13'), ('219', '59'), ('220', '17'), ('221', '9'), ('222', '51'), ('223', '26'), ('224', '39'), ('225', '39'), ('226', '35'), ('227', '18'), ('228', '45'), ('229', '36'), ('230', '34'), ('231', '30'), ('232', '34'), ('233', '36'), ('234', '14'), ('235', '7'), ('236', '28'), ('237', '34'), ('238', '49'), ('239', '95'), ('240', '66'), ('241', '36'), ('242', '32'), ('243', '25'), ('244', '25'), ('245', '30'), ('246', '15'), ('247', '12'), ('248', '40'), ('249', '32'), ('250', '26'), ('251', '18'), ('252', '60'), ('253', '21'), ('254', '79'), ('255', '17'), ('256', '42'), ('257', '40'), ('258', '23'), ('259', '39'), ('260', '58'), ('261', '19'), ('262', '45'), ('263', '17'), ('264', '66'), ('265', '31'), ('266', '25'), ('267', '38'), ('268', '16'), ('269', '36'), ('270', '20'), ('271', '29'), ('272', '26'), ('273', '32'), ('274', ' ...

# %% [markdown]
# ¿Cuantas filas hay en la base de datos?

# %%
#Escribir el codigo para responder la pregunta en esta celda
print(len(to_db))
# Out:
# 10000

# %% [markdown]
# ¿Cual es el máximo `GameLength` y en qué `GameNumber` se realizó?

# %%
#Escribir el codigo para responder la pregunta en esta celda
max(to_db)
# Out:
# ('9999', '9')

# %% [markdown]
# # API Requests
# Por lo general, conseguimos datos a traves de internet. Aunque el concepto de Application Programming Interface (API) es muy amplio y muy poco concreto, en el contexto de los servidores, es un conjunto de 'endpoints' que los servidores ofrecen para poder leer/procesar/escribir información en estos mismos.
#
# [En este repositorio](https://github.com/public-apis/public-apis) van a encontrar una lista de APIs públicas (pueden elegir otras que no son de ese repositorio). Para la consigna, se recomienda usar aquellas APIs que no requieren autenticación. Si se elige una API con autenticación, por favor, adjuntar las keys o pasarl las credenciales necesarias para su futura ejecución También, pueden usar varias URLs.

# %% [markdown]
# ## Consigna

# %% [markdown]
# Hacer una request GET e imprimir uno de los campos de la respuesta:

# %%
import requests
url="https://api.fiscaldata.treasury.gov/services/api/fiscal_service/v1/accounting/od/rates_of_exchange"
datos=requests.get(url)
jason=datos.json()
print(jason)
# Out:
# {'data': [{'record_date': '2001-03-31', 'country': 'Afghanistan', 'currency': 'Afghani', 'country_currency_desc': 'Afghanistan-Afghani', 'exchange_rate': '78400.0', 'effective_date': '2001-03-31', 'src_line_nbr': '1', 'record_fiscal_year': '2001', 'record_fiscal_quarter': '2', 'record_calendar_year': '2001', 'record_calendar_quarter': '1', 'record_calendar_month': '03', 'record_calendar_day': '31'}, {'record_date': '2001-03-31', 'country': 'Albania', 'currency': 'Lek', 'country_currency_desc': 'Albania-Lek', 'exchange_rate':
 'Schilling', 'country_currency_desc': 'Austria-Schilling', 'exchange_rate': '14.908', 'effective_date': '2001-03-31', 'src_line_nbr': '10', 'record_fiscal_year': '2001', 'record_fiscal_quarter': '2', 'record_calendar_year': '2001', 'record_calendar_quarter': '1', 'record_calendar_month': '03', 'record_calendar_day': '31'}, {'record_date': '2001-03-31', 'country': 'Azerbaidjan', 'currency': 'Second Manat', 'country_currency_desc': 'Azerbaidjan-Second M ...

# %% [markdown]
# #Escribir el codigo para responder la pregunta en esta celda
# import requests
# url = "https://api.fiscaldata.treasury.gov/services/api/fiscal_service/v1/accounting/od/rates_of_exchange"
# response = requests.get(url)
# print(response)

# %% [markdown]
# Hacer una request GET y, apartir de los campos en la respuesta, generar otro campo (por ejemplo, si la respuesta solo incluye un timestamp y una posición del registro, elaborar la velocidad del registro)

# %%
#Escribir el codigo para responder la pregunta en esta celda
from datetime import date
lstjson=jason["data"]
index1jason=lstjson[1]
lst={"run_date":f"{date.today()}"}
index1jason.update(lst)
print(index1jason)
# Out:
# {'record_date': '2001-03-31', 'country': 'Albania', 'currency': 'Lek', 'country_currency_desc': 'Albania-Lek', 'exchange_rate': '142.4', 'effective_date': '2001-03-31', 'src_line_nbr': '2', 'record_fiscal_year': '2001', 'record_fiscal_quarter': '2', 'record_calendar_year': '2001', 'record_calendar_quarter': '1', 'record_calendar_month': '03', 'record_calendar_day': '31', 'run_date': '2024-11-19'}

# %% [markdown]
# # Streaming data
# Ahora vamos a hacer algo muy parecido a lo anterior, pero vamos a usar APIs que nos ofrecen datos en tiempo real. Pueden encontrar APIs de este estilo [en este repositorio](https://github.com/ColinEberhardt/awesome-public-streaming-datasets) (pueden elegir otras que no son de ese repositorio)

# %% [markdown]
# ## Consigna

# %% [markdown]
# Hacer un plot con `matplotlib` de una variable de una API de datos streaming en el que el eje 'y' sea la variable y el eje 'x' el tiempo.

# %%
import matplotlib.pyplot as plt
url = "https://api.open-meteo.com/v1/forecast"
params = {
    "latitude": 52.52,
    "longitude": 13.41,
    "hourly": "temperature_2m,relative_humidity_2m,wind_speed_10m",
    "current_weather": True,
    "start_date": "2024-11-18",
    "end_date": "2024-11-18",
}

response = requests.get(url, params=params)
if response.status_code == 200:
  data = response.json()
  hourly = data["hourly"]
  times = hourly["time"]
  temperature = hourly["temperature_2m"]
  wind_speed = hourly["wind_speed_10m"]
  humidity = hourly["relative_humidity_2m"]
  times_readable = [time.split("T")[1][:5] for time in times]
  plt.figure(figsize=(12, 6))
  plt.plot(times_readable, temperature, label="Temperature (°C)", color="red")
  plt.plot(times_readable, wind_speed, label="Wind Speed (m/s)", color="blue")
  plt.plot(times_readable, humidity, label="Relative Humidity (%)", color="green")
  plt.title("Weather Data (Hourly)")
  plt.xlabel("Time (hh:mm)")
  plt.ylabel("Values")
  plt.legend()
  plt.grid()
  plt.xticks(rotation=45)
  plt.tight_layout()
  plt.show()

else:
    print(f"Error: {response.status_code} - {response.text}")
